# %% [markdown]
# First, import the necessary packages.

# %%
#Import the libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Layer, Conv2D, Flatten, Dense, Reshape, Conv2DTranspose
import matplotlib.pyplot as plt

# %% [markdown]
# In VAEs, the sampling layer uses the output from two dense layers, z_mean and z_log_var, as inputs, followed by converting them into the normal distribution and passing them to the decoder layer.

# %%
#Sampling layer
class Sampling(Layer):

	def call(self, inputs):
		z_mean, z_log_var = inputs
		batch = tf.shape(z_mean)[0]
		dim = tf.shape(z_mean)[1]
		epsilon = tf.keras.backend.random_normal(shape =(batch, dim))
		return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# Here, we are defining the architecture of the encoder part of this autoencoder, which takes images as input, followed by encoding their representation in the sampling layer.

# %%
# Define Encoder Model
latent_dim = 2

encoder_inputs = Input(shape =(28, 28, 1))
x = Conv2D(32, 3, activation ="relu", strides = 2, padding ="same")(encoder_inputs)
x = Conv2D(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Flatten()(x)
x = Dense(16, activation ="relu")(x)
z_mean = Dense(latent_dim, name ="z_mean")(x)
z_log_var = Dense(latent_dim, name ="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name ="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)             18496     ['conv2d[0][0]']
#
#  flatten (Flatten)           (None, 3136)                 0         ['conv2d_1[0][0]']
#
#  dense (Dense)               (None, 16)                   50192     ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 2)                    34        ['dense[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    34        ['dense[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69076 (269.83 KB)
# Trainable params: 69076 (269.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# In this step, we are defining the architecture of the decoder part of the autoencoder, where the output of the sampling layer is given as input and produces an output image of size (28, 28, 1) .

# %%
# Define Decoder Architecture
latent_inputs = keras.Input(shape =(latent_dim, ))
x = Dense(7 * 7 * 64, activation ="relu")(latent_inputs)
x = Reshape((7, 7, 64))(x)
x = Conv2DTranspose(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Conv2DTranspose(32, 3, activation ="relu", strides = 2, padding ="same")(x)
decoder_outputs = Conv2DTranspose(1, 3, activation ="sigmoid", padding ="same")(x)
decoder = Model(latent_inputs, decoder_outputs, name ="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# In this step, we are defining the complete variational autoencoder architecture, followed by defining the training procedure with loss functions.

# %%
#Define the complete variational autoencoder architecture
class VAE(keras.Model):
	def __init__(self, encoder, decoder, **kwargs):
		super(VAE, self).__init__(**kwargs)
		self.encoder = encoder
		self.decoder = decoder

	def train_step(self, data):
		if isinstance(data, tuple):
			data = data[0]
		with tf.GradientTape() as tape:
			z_mean, z_log_var, z = encoder(data)
			reconstruction = decoder(z)
			reconstruction_loss = tf.reduce_mean(
				keras.losses.binary_crossentropy(data, reconstruction)
			)
			reconstruction_loss *= 28 * 28
			kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
			kl_loss = tf.reduce_mean(kl_loss)
			kl_loss *= -0.5
			total_loss = reconstruction_loss + kl_loss
		grads = tape.gradient(total_loss, self.trainable_weights)
		self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
		return {
			"loss": total_loss,
			"reconstruction_loss": reconstruction_loss,
			"kl_loss": kl_loss,
		}

# %% [markdown]
# Here, we shall train the variational autoencoder model for 50 epochs after importing the fashion MNIST dataset.

# %%
#Load the fashion mnist dataset
(x_train, _), (x_test, _) = keras.datasets.fashion_mnist.load_data()
fmnist_images = np.concatenate([x_train, x_test], axis = 0)
#Expansion of dimension for adding a color map dimension
fmnist_images = np.expand_dims(fmnist_images, -1).astype("float32") / 255

#Compile and train the VAE model
vae = VAE(encoder, decoder)
vae.compile(optimizer ='rmsprop')
vae.fit(fmnist_images, epochs = 50, batch_size = 64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1094/1094 [==============================] - 19s 7ms/step - loss: 296.9776 - reconstruction_loss: 292.9489 - kl_loss: 4.0288
# Epoch 2/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 272.0211 - reconstruction_loss: 268.5494 - kl_loss: 3.4718
# Epoch 3/50
# 1094/1094 [==============================] - 11s 10ms/step - loss: 268.2793 - reconstruction_loss: 264.8906 - kl_loss: 3.3887
# Epoch 4/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 265.6113 - reconstruction_loss: 262.1991 - kl_loss: 3.4122
# Epoch 5/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 263.5661 - reconstruction_loss: 260.0950 - kl_loss: 3.4711
# Epoch 6/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 261.9844 - reconstruction_loss: 258.4896 - kl_loss: 3.4948
# Epoch 7/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 260.9245 - reconstruction_loss: 257.4049 - kl_loss: 3.5196
# Epoch 8/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 260.0439 - reconstruction_loss: 256.5038 - kl_loss: 3.5401
# Epoch 9/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 259.4558 - reconstruction_loss: 255.9028 - kl_loss: 3.5530
# Epoch 10/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 258.8996 - reconstruction_loss: 255.3308 - kl_loss: 3.5688
# Epoch 11/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 258.4871 - reconstruction_loss: 254.9138 - kl_loss: 3.5733
# Epoch 12/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 258.1086 - reconstruction_loss: 254.5208 - kl_loss: 3.5878
# Epoch 13/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 257.7409 - reconstruction_loss: 254.1540 - kl_loss: 3.5868
# Epoch 14/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 257.4540 - reconstruction_loss: 253.8444 - kl_loss: 3.6096
# Epoch 15/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 257.1747 - reconstruction_loss: 253.5715 - kl_loss: 3.6032
# Epoch 16/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 257.0041 - reconstruction_loss: 253.3835 - kl_loss: 3.6206
# Epoch 17/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 256.7232 - reconstruction_loss: 253.0972 - kl_loss: 3.6260
# Epoch 18/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 256.5433 - reconstruction_loss: 252.9068 - kl_loss: 3.6365
# Epoch 19/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 256.3075 - reconstruction_loss: 252.6714 - kl_loss: 3.6362
# Epoch 20/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 256.1570 - reconstruction_loss: 252.5112 - kl_loss: 3.6457
# Epoch 21/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.9811 - reconstruction_loss: 252.3250 - kl_loss: 3.6561
# Epoch 22/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.8555 - reconstruction_loss: 252.1834 - kl_loss: 3.6721
# Epoch 23/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.6681 - reconstruction_loss: 252.0017 - kl_loss: 3.6664
# Epoch 24/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.5088 - reconstruction_loss: 251.8260 - kl_loss: 3.6827
# Epoch 25/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.3543 - reconstruction_loss: 251.6748 - kl_loss: 3.6795
# Epoch 26/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.2393 - reconstruction_loss: 251.5463 - kl_loss: 3.6930
# Epoch 27/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.1152 - reconstruction_loss: 251.4167 - kl_loss: 3.6986
# Epoch 28/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.0414 - reconstruction_loss: 251.3364 - kl_loss: 3.7050
# Epoch 29/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.9174 - reconstruction_loss: 251.2000 - kl_loss: 3.7174
# Epoch 30/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.8228 - reconstruction_loss: 251.0975 - kl_loss: 3.7253
# Epoch 31/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.7037 - reconstruction_loss: 250.9863 - kl_loss: 3.7174
# Epoch 32/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.5931 - reconstruction_loss: 250.8755 - kl_loss: 3.7175
# Epoch 33/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.4810 - reconstruction_loss: 250.7453 - kl_loss: 3.7357
# Epoch 34/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.4200 - reconstruction_loss: 250.6859 - kl_loss: 3.7341
# Epoch 35/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.3056 - reconstruction_loss: 250.5649 - kl_loss: 3.7407
# Epoch 36/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.2053 - reconstruction_loss: 250.4489 - kl_loss: 3.7564
# Epoch 37/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 254.1545 - reconstruction_loss: 250.3995 - kl_loss: 3.7550
# Epoch 38/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.0628 - reconstruction_loss: 250.3084 - kl_loss: 3.7544
# Epoch 39/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 254.0457 - reconstruction_loss: 250.2824 - kl_loss: 3.7633
# Epoch 40/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.9310 - reconstruction_loss: 250.1699 - kl_loss: 3.7611
# Epoch 41/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.8659 - reconstruction_loss: 250.0922 - kl_loss: 3.7737
# Epoch 42/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.8281 - reconstruction_loss: 250.0552 - kl_loss: 3.7730
# Epoch 43/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.7152 - reconstruction_loss: 249.9355 - kl_loss: 3.7797
# Epoch 44/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 253.6841 - reconstruction_loss: 249.9110 - kl_loss: 3.7731
# Epoch 45/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.6145 - reconstruction_loss: 249.8260 - kl_loss: 3.7885
# Epoch 46/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.5540 - reconstruction_loss: 249.7609 - kl_loss: 3.7932
# Epoch 47/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.4344 - reconstruction_loss: 249.6481 - kl_loss: 3.7863
# Epoch 48/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 253.5010 - reconstruction_loss: 249.7099 - kl_loss: 3.7911
# Epoch 49/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 253.4163 - reconstruction_loss: 249.6165 - kl_loss: 3.7998
# Epoch 50/50
# 1094/1094 [==============================] - 6s 6ms/step - loss: 253.3230 - reconstruction_loss: 249.5355 - kl_loss: 3.7875

# %% [markdown]
# Here we are displaying training results according to their latent space vectors.

# %%
def plot_latent(encoder, decoder):
	n = 9
	img_dim = 28
	scale = 2.0
	figsize = 15
	figure = np.zeros((img_dim * n, img_dim * n))

	grid_x = np.linspace(-scale, scale, n)
	grid_y = np.linspace(-scale, scale, n)[::-1]

	for i, yi in enumerate(grid_y):
		for j, xi in enumerate(grid_x):
			z_sample = np.array([[xi, yi]])
			x_decoded = decoder.predict(z_sample)
			images = x_decoded[0].reshape(img_dim, img_dim)
			figure[
				i * img_dim : (i + 1) * img_dim,
				j * img_dim : (j + 1) * img_dim,
			] = images

	plt.figure(figsize =(figsize, figsize))
	start_range = img_dim // 2
	end_range = n * img_dim + start_range + 1
	pixel_range = np.arange(start_range, end_range, img_dim)
	sample_range_x = np.round(grid_x, 1)
	sample_range_y = np.round(grid_y, 1)
	#plt.xticks(pixel_range, sample_range_x)
	#plt.yticks(pixel_range, sample_range_y)
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.imshow(figure, cmap ="Greys_r")
	plt.show()


plot_latent(encoder, decoder)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# The scatter plot of the training data generated from the encoder has been generated to get a clear idea of the latent vector values.

# %%
def plot_label_clusters(encoder, decoder, data, test_lab):
	z_mean, _, _ = encoder.predict(data)
	plt.figure(figsize =(12, 10))
	sc = plt.scatter(z_mean[:, 0], z_mean[:, 1], c = test_lab)
	cbar = plt.colorbar(sc, ticks = range(10))
	cbar.ax.set_yticklabels([labels.get(i) for i in range(10)])
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.show()


labels = {0 :"T-shirt / top",
1: "Trouser",
2: "Pullover",
3: "Dress",
4: "Coat",
5: "Sandal",
6: "Shirt",
7: "Sneaker",
8: "Bag",
9: "Ankle boot"}

(x_train, y_train), _ = keras.datasets.fashion_mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
plot_label_clusters(encoder, decoder, x_train, y_train)
# Out:
# 1875/1875 [==============================] - 3s 2ms/step
